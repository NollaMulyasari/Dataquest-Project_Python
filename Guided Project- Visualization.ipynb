# %% [markdown]
# # Guided Project
# ## Visualizing Earnings Based on College Majors
#
# We will be working with a dataset on the job outcomes of students who graduated from college between 2010 and 2012. The original data on job outcome was released by [<font color='green'>American Community Survey</font>](https://www.census.gov/programs-surveys/acs/), which conducts surveys and aggregate the data.
#
# In this project we will explore how using visualization, we can start to explore question from the dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
recent_grads = pd.read_csv('recent-grads.csv')
recent_grads.iloc[0]
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
recent_grads.head(10)
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
# 5     6        2418                        NUCLEAR ENGINEERING   2573.0
# 6     7        6202                          ACTUARIAL SCIENCE   3777.0
# 7     8        5001                 ASTRONOMY AND ASTROPHYSICS   1792.0
# 8     9        2414                     MECHANICAL ENGINEERING  91227.0
# 9    10        2408                     ELECTRICAL ENGINEERING  81527.0
#
#        Men    Women     Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0        Engineering    0.120564           36      1976
# ...

# %%
recent_grads.tail(10)
# Out:
#      Rank  Major_code                                          Major    Total  \
# 163   164        6102  COMMUNICATION DISORDERS SCIENCES AND SERVICES  38279.0
# 164   165        2307                      EARLY CHILDHOOD EDUCATION  37589.0
# 165   166        2603                        OTHER FOREIGN LANGUAGES  11204.0
# 166   167        6001                         DRAMA AND THEATER ARTS  43249.0
# 167   168        3302                       COMPOSITION AND RHETORIC  18953.0
# 168   169        3609                                        ZOOLOGY   8409.0
# 169   170        5201                         EDUCATIONAL PSYCHOLOGY   2854.0
# 170   171        5202                            CLINICAL PSYCHOLOGY   2838.0
# 171   172        5203                          COUNSELING PSYCHOLOGY   4626.0
# 172   173        3501                                LIBRARY SCIENCE   1098.0
#
#          Men    Women             Major_category  ShareWomen  Sample_size  \
# ...

# %%
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
raw_data_count = recent_grads.shape[0]
raw_data_count
# Out:
# 173

# %% [markdown]
# Let's drop the rows that has NaN as values

# %%
recent_grads = recent_grads.dropna()

#lookup the number of rows 
cleaned_data_count = recent_grads.shape[0]
cleaned_data_count
# Out:
# 172

# %% [markdown]
# ## Pandas Scatter plot

# %%
recent_grads.plot(x="Sample_size", y="Median", kind="scatter", title="Sample_size vs. Median")

# %%
recent_grads.plot(x="Sample_size", y="Unemployment_rate", kind="scatter", title ="Sample_size vs. Unemployment_rate")

# %%
recent_grads.plot(x="Full_time", y="Median", kind="scatter", title="Full_time vs. Median")

# %%
recent_grads.plot(x="ShareWomen", y= "Unemployment_rate", kind="scatter", title="ShareWomen vs. Unemployment_rate")

# %%
recent_grads.plot(x="Men", y="Median", kind="scatter", title= "Men vs Median")

# %%
recent_grads.plot(x="Women", y="Median", kind="scatter", title="Women vs Median")

# %% [markdown]
# ## Histogram plot

# %%
recent_grads["Sample_size"].plot(kind="hist", title="Sample_size")

# %%
recent_grads["Median"].hist(bins=25, range=(0,120000))

# %%
recent_grads["Employed"].hist(bins=25, range=(0,350000))

# %%
recent_grads["Full_time"].hist(bins=25, range=(0,300000))

# %%
recent_grads["ShareWomen"].plot(kind="hist", title="ShareWomen")

# %%
recent_grads["Unemployment_rate"].plot(kind="hist", title="Unemplyoment Rate")

# %%
recent_grads["Men"].hist(bins=20, range=(0,180000))

# %%
recent_grads["Women"].hist(bins=20, range=(0,200000))

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(recent_grads[["Sample_size", "Median"]], figsize=(6,6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb46d949c18>,
# ...
#       dtype=object)

# %%
scatter_matrix(recent_grads[["Sample_size", "Median", "Unemployment_rate"]], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb46d66cbe0>,
# ...
#       dtype=object)

# %% [markdown]
# ## Bar Plots

# %%
recent_grads[:10].plot.bar(x="Major", y="ShareWomen", legend=False)
recent_grads[163:].plot.bar(x="Major", y="ShareWomen", legend=False)

# %%
recent_grads[:10].plot.bar(x="Major", y="Unemployment_rate", legend=False)
recent_grads[163:].plot.bar(x="Major", y="Unemployment_rate", legend=False)
